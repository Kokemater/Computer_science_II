# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mass2_inel = 204 # gramos
mass1_inel = 200 # gramos
mass1_el = 200 # gramos
mass2_el = 191 #gramos

dmass = 1  #gramos

long1 = 10 #cm
long2 = 10 #cm
dlong = 0.1 #cm

# %% [markdown]
# COLISIÓN ELÁSTICA CON DISTINTOS PESOS

# %%
# [mass1_el, mass2_el, t1_i, t2_i, t1_f, t2_f ]
tabla_el = [
	[200, 400+4, 0.290 , 0, 0.938, 0.446 ],
	[200, 400+4, 0.285 , 0, 0.934, 0.443],
	[200, 400+4, 0.135, 0, 0.431, 0.212],

	[200, 350+4, 0.106 , 0, 0.459, 0.164],
	[200, 350+4, 0.093 , 0, 0.429, 0.145],
	[200, 350+4, 0.093 , 0, 0.430, 0.120],

	[200, 300+4, 0.183 , 0, 1.529, 0.236],
	[200, 300+4, 0.147 , 0, 1.184, 0.193],
	[200, 300+4, 0.157 , 0, 0.886, 0.204],

	[200, 250+4, 0.084 , 0, 1.088, 0.106],
	[200, 250+4, 0.097 , 0, 0.995, 0.122],
	[200, 250+4, 0.101 , 0, 1.072, 0.126],


#[400, 400+4, 0.147 , 0, 1.184, 0.193],
#	[400, 400+4, 0.147 , 0, 1.184, 0.193],
		 ]
tabla_el = np.array(tabla_el)

# %% [markdown]
# Nótese que sólo se recogen datos desde x 1.3 hasta 2, esto se debe a que los datos recogidos durante el experimento en relacciones de masa \( \frac{m2}{m1} <= 1 \) la masa 1 se quedaba completamente detenida tras chocar a la masa 2, sin retroceder. Esto puede deberse a un error experimental debido a la presencia de rozamiento durante el experimento, la solución a este problema podría ser lubricar la superficie en la que las masas se desplazan.

# %%
# [mass1_el, mass2_el, t1_i, t2_i, t1_i, t2_f ]

v_1_i = long1 / tabla_el[:, 2]
v_1_f = -long1 / tabla_el[:, 4]
v_2_f = long2 / tabla_el[:, 5]
v1f_v1i = v_1_f / v_1_i
v2f_v1i = v_2_f / v_1_i


m2_m1 = tabla_el[:,1] / tabla_el[:,0]

# Graficar varias listas en una misma gráfica
plt.plot(m2_m1, v1f_v1i, 'o', label="v1f_v1i")  # Graficar y1
plt.plot(m2_m1, v2f_v1i, 's', label ="v2f_v1i")  # Graficar y2
mass_ratio = np.linspace(0.5, 2, 500)
v1f_v1i = (1 - mass_ratio) / (1 + mass_ratio)
v2f_v1i = 2 / (1 + mass_ratio)
plt.plot(mass_ratio, v1f_v1i, label=r'$v_{1f}/v_{1i}$', color='blue')
plt.plot(mass_ratio, v2f_v1i, label=r'$v_{2f}/v_{1i}$', color='red')
# Agregar etiquetas y título
plt.xlabel(r'$\frac{m_2}{m_1}$')
plt.ylabel(r'y')
plt.title('Colisiones elásticas')

# Mostrar leyenda para diferenciar las listas
plt.legend()

# Mostrar la cuadrícula
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %%
v1f_v2f = v_1_f/v_2_f
v1i_v2f = v_1_i/v_2_f


print(m2_m1)
print(v1i_v2f)
mass_ratio = np.linspace(0.5, 2, 500)

# Graficar varias listas en una misma gráfica
plt.plot(m2_m1, v1f_v2f, 'o', label="v1f_v2f")  # Graficar y1
plt.plot(m2_m1, v1i_v2f, 's', label="v1i_v2f")  # Graficar y2
v1f_v2f = (1 - mass_ratio) / (2)
v1i_v2f = (1 + mass_ratio) / (2)
plt.plot(mass_ratio, v1f_v2f, label=r'$v_{1f}/v_{2f}$ teórico', color='green')
plt.plot(mass_ratio, v1i_v2f, label=r'$v_{1i}/v_{2f}$ teórico', color='purple')
v1f_v1i = (1 - mass_ratio) / (1 + mass_ratio)
v2f_v1i = 2 / (1 + mass_ratio)
v1f_v2f = (1 - mass_ratio) / (2)
v1i_v2f = (1 + mass_ratio) / (2)

plt.title(r'Razones $v_{1f}/v_{1i}$ y $v_{2f}/v_{1i}$')
# Agregar etiquetas y título
plt.xlabel(r'$\frac{m_2}{m_1}$')
plt.ylabel('y')
plt.title('Colisiones elásticas')

# Mostrar leyenda para diferenciar las listas
plt.legend()

# Mostrar la cuadrícula
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# [2.02 2.02 2.02 1.77 1.77 1.77 1.52 1.52 1.52 1.27 1.27 1.27]
# [1.53793103 1.55438596 1.57037037 1.54716981 1.55913978 1.29032258
#  1.28961749 1.31292517 1.29936306 1.26190476 1.25773196 1.24752475]

# %%
# [mass1_el, mass2_el, t1_i, t2_f ]

tabla_inel = [
	[200, 400-10, 0.129+0.02 , 0, 0.457+0.02 ],
	[200, 400-10, 0.192+0.02 , 0, 0.571 +0.02],

	[200, 300-10, 0.145 , 0, 0.359],
	[200, 300-10, 0.142, 0,0.359],
	
	[200, 200-10, 0.240, 0, 0.449],
	[200, 200-10, 0.197, 0, 0.393],

	[300, 200-10, 0.161, 0, 0.276],
	[300, 200-10, 0.333, 0, 0.530],

	[400, 200-10, 0.234, 0, 0.344],
	[400, 200-10, 0.216, 0, 0.328],
	]
tabla_inel = np.array(tabla_inel)

# %%
# [mass1_el, mass2_el, t1_i, t2_i, t2_f ]

v_i = long1 / tabla_inel[:, 2] 
v_f = long2 / tabla_inel[:, 4]
E_i = 0.5* tabla_inel[:,0] * v_i**2
E_f = 0.5*(tabla_inel[:,0] + tabla_inel[:,1])  * v_f**2

Ef_Ei = E_f / E_i

vf_vi = v_f / v_i

m2_m1 = tabla_inel[:,1] / tabla_inel[:,0]

print(m2_m1)
print(vf_vi)
plt.plot(m2_m1, Ef_Ei, 'o', label="Ef_Ei")
plt.plot(m2_m1, vf_vi, 'o', label='vf/vi')
x = np.linspace(0.4, 2.1, 100)
y = 1 / (1 + x)
plt.plot(x,y, '-', label="Ef_Ei teoría")
plt.plot(x,y, '--', label="vf/vi teoría")

plt.xlabel(r'$\frac{m_2}{m_1}$')
plt.ylabel('y')
plt.title('Colisiones inelásticas')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [1.95       1.95       1.45       1.45       0.95       0.95
#  0.63333333 0.63333333 0.475      0.475     ]
# [0.31236897 0.35871404 0.40389972 0.39554318 0.53452116 0.50127226
#  0.58333333 0.62830189 0.68023256 0.65853659]
